# %% [markdown]
# ## Task 3 - Computer Vision

# %% [markdown]
# ### Beginner
# Take pre-trained model for imege classification (ex. MobileNetV2). Pick one image from the Internet (any you like), pre-proccess it, make it black and white instead of RGB, try to find out if the is some Gaussian noise (maybe get rid of it), pass to model and print top 5 classified classess of the image.

# %%
from keras.applications.mobilenet_v2 import MobileNetV2, preprocess_input, decode_predictions

# %%
model = MobileNetV2(weights='imagenet')

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
# take an image -> resize it
image=cv2.imread("ananas_image.jpg")
image = cv2.resize(image, (224, 224), 
               interpolation = cv2.INTER_LINEAR)

plt.imshow(image[:,:,::-1]) #cv2 has reversed colormap RGB->BRG

# %%
# make the photo gray
gray_image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
plt.imshow(gray_image,cmap="gray")

# %%
data = np.empty((1,224,224,3))
data[0] = preprocess_input(image)
predictions = model.predict(data)
# Out:
# 1/1 [==============================] - 3s 3s/step

# %%
decode_predictions(predictions, top=5)
# Out:
# [[('n07753275', 'pineapple', 0.6665103),
#   ('n04209133', 'shower_cap', 0.014531983),
#   ('n07715103', 'cauliflower', 0.011014707),
#   ('n07745940', 'strawberry', 0.005743974),
#   ('n03924679', 'photocopier', 0.0054416256)]]

# %% [markdown]
# Wow it is `pineapple 🍍` - maybe
